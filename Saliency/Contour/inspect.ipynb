# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
ml = pd.read_csv("/lustre/storeB/users/arefk/MScThesis_AreKvanum2022_SeaIceML/ForecastValidation/lead_time_2/weights_21021550.csv", index_col = 0)
edges = pd.read_csv("/lustre/storeB/users/arefk/MScThesis_AreKvanum2022_SeaIceML/Saliency/Contour/displacement_to_saliency.csv", index_col = 0)

# %%
edges
# Out:
#             arome_displacement  icechart_displacement
# date
# 2022-01-03        46007.109095           34131.364852
# 2022-01-04        69305.775857           59091.677714
# 2022-01-05        78252.835403           67451.703922
# 2022-01-10        75907.563921           55340.195711
# 2022-01-11        57784.342985           39470.697748
# ...                        ...                    ...
# 2022-12-19        71363.158386           61340.263786
# 2022-12-20        39569.501333           25147.032661
# 2022-12-21        43345.902370           25739.766555
# 2022-12-27        70737.206898           44189.152588
# 2022-12-28        63746.434104           46438.802508
#
# [147 rows x 2 columns]

# %%
fig, ax = plt.subplots(figsize = (14, 14))
ax.scatter(edges['arome_displacement'], edges['icechart_displacement'], 1)

for i, txt in enumerate(ml['NIIEE_2']):
    ax.annotate(f"{txt:.0f}", (edges['arome_displacement'][i], edges['icechart_displacement'][i]))

ax.set_xlabel('arome displacement')
ax.set_ylabel('icechart displacement')
fig.tight_layout()
